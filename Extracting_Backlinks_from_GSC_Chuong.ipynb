# %% [markdown]
# <a href="https://colab.research.google.com/github/AncalagonDBlack/Heinzno1Code/blob/master/Extracting_Backlinks_from_GSC_Chuong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://tealfeed.com/methods-extracting-backlinks-google-search-console-cqwwm

# %% [markdown]
# https://medium.com/@liviuoltean/seo-how-to-scrape-googles-search-console-for-backlinks-data-3893503cf128

# %%
from bs4 import BeautifulSoup
import requests,time
import re
import pandas as pd
import csv
input="bbcincorp.com" #nhập domain zô
headers = {
    "authority": "search.google.com",
    "method":"GET",
    "path":f"/search-console/links?resource_id=https%3A%2F%2F{input}%2F",
    "scheme":"https",  
    "accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "accept-encoding":"gzip, deflate, br",
    "accept-language":"en-GB,en-US;q=0.9,en;q=0.8,ro;q=0.7",
    "cache-control":"no-cache",
    "pragma":"no-cache",
    "sec-ch-ua":"navigate",
    "sec-fetch-site":"same-origin",
    "sec-fetch-user":"?1",
    "upgrade-insecure-requests":"1",
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36",
    "x-client-data":"CJG2yQEIpLbJAQjBtskBCKmdygEI94LLAQiUocsBCLi8zAEI6rzMAQjE4cwBCMXhzAEI2OjMAQj/6MwBCPPqzAEInezMAQjm8cwB",
    "sec-ch-ua":'" Not A;Brand";v="99", "Chromium";v="100", "Google Chrome";v="100"',
    "sec-ch-ua-mobile": "?0",
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate"
}
cookies = {
    "__Secure-1PAPISID":"uZKOxDcrZjCVLr8w/AUgMGP1n_RZFDwOny", #:"[your-info]", cập nhật cái này
    "__Secure-1PSID":"RAhTwvtl6jGHZM42x_JFhvaY0TpMYS_Y9av4TafUZjYD7fuRmVC86Ky6QYf9S0BKNktt7A.",#:"[your-info]",
    "__Secure-3PAPISID":"uZKOxDcrZjCVLr8w/AUgMGP1n_RZFDwOny",#:"[your-info]",
    "__Secure-3PSID":"RAhTwvtl6jGHZM42x_JFhvaY0TpMYS_Y9av4TafUZjYD7fuRMqt_tQiHH9_uQNblWeTQqw.",#:"[your-info]",
    "__Secure-3PSIDCC":"AIKkIs1uNLoSII4P6HmIJ_WUecjSi-jbPyfoBawpqtnlGfJbmIlhZHQx_dwQ_sRYoZZMCLjjTfRP",#:"[your-info]", cập nhật cái này
    "1P_JAR":"2022-12-06-02",#:"[your-info]",
    "NID":"511=eUe-2Errdmsb5BDzFJIVgVqAnXTsJna94Pk4Bhlp3DNw4r1aqFSupZEZShjrPZ8wSqCqdR2E9B-T8H7DITYuTerIfyISA77g_5vW0IdPA3xhdC5-wSM_8BiRdAlh1uq9WQ3reHHwlmxtXNNF3zRrD3fQe_fmpO-rVbQZZlB-O9jkjbGuqv37cp0O8TF3VDAOJ3LfK4pDFFLs7Y-CAzOLPMB_1MHhGVxSrpZmW1bEhUJQC_D-sPCOJLYumV5RXBsOWobBhwIRR-RoOq6cmriN2dgUQuWJKWcrbkv2KpiNugNIb271YA",
    "APISID":"rgrhqcjUWJcEfFeW/AcoCm6A1bzlMERU4W",#:"[your-info]",
    #"CONSENT":"[your-info]",
    "HSID":"AHHcNUUa0bfeBtmZz",#:"[your-info]",
    "SAPISID":"mk6G4eX2sEe4x9jD/Al_rQGMO0iNjnbrUH",#:"[your-info]",
    "SID":"RAhTwvtl6jGHZM42x_JFhvaY0TpMYS_Y9av4TafUZjYD7fuRdvCuLHhvvWzVaYVdd-pf_Q.",#:"[your-info]",
    "SIDCC":"AIKkIs2uWPptMRub5CX4sTNczY1uC5Rm4-iRdQt6QPmJCU8vIfMhWn0iJfGs2kdC1fa9__oZh9M",#:"[your-info]", cập nhật cái này
    "SSID":"Aawy0uTu1GSAlR-de",#:"[your-info]",
    "_ga":"GA1.3.760922900.1610505979",#:"[your-info]",
    #"OGPC":"[your-info]",
    "OTZ":"6790043_28_28__28_"#:"[your-info]", ít đổi
}

# %%
genericURL = f"https://search.google.com/search-console/links/drilldown?resource_id=https%3A%2F%2F{input}%2F&type=DOMAIN&target=&domain="
req = requests.get(genericURL, headers=headers, cookies=cookies)
soup = BeautifulSoup(req.content, 'html.parser')
print(soup) #check soup

# %%
regex = re.compile('nJ0sOc wNFy3d ptEsvc*')
g_data = soup.findAll("tr", {"class": regex})
dfdomains = pd.DataFrame()
print(g_data)
countchovui=0
# Out:
# [<tr class="nJ0sOc wNFy3d ptEsvc " data-rowid="0" jsaction="click:AJI9fd;" jscontroller="qLYC9e" jsshadow=""><td class="XgRaPc AB6Eee QNcORc HSWdnb LoCYSb G49IUc chZ7Tc XL1mme"><span class="zRhise" jsslot=""><span class="PkjLuf " title="codigosdepaises.pro"><div class="OOHai">codigosdepaises.pro<div class="qUFtbf"><div class="vhSllf" jsaction="click:cOuCgd" jscontroller="ifmJ5b"><span class="DPvwYc QiuYjb ERSyJd" data-column-type="12" data-value="codigosdepaises.pro" title="Sao chép URL vào bảng nhớ tạm"></span></div><div class="vhSllf" jsaction="click:cOuCgd" jscontroller="ifmJ5b"><span class="DPvwYc QiuYjb Qb2M8" data-column-type="12" data-value="codigosdepaises.pro" title="Mở trong thẻ mới"></span></div></div></div></span></span></td><td class="XgRaPc QNcORc HSWdnb XL1mme" data-numeric-value="982"><span class="zRhise" jsslot=""><span class="PkjLuf ">982<div class="qUFtbf"></div></span></span></td><td class="XgRaPc QNcORc HSWdnb XL1mme" data-numeric-value="174"><span class="zRhise" jsslot=""><span class="PkjLuf ">174<div class="qUFtbf"></div></span></span></td></tr>, <tr class="nJ0sOc wNFy3d ptEsvc " data-rowid="1" jsaction="click:AJI9fd;" jscontroller="qLYC9e" jsshadow=""><td class="XgRaPc AB6Eee QNcORc HSWdnb LoCYSb G49IUc chZ7Tc XL1mme"><span class="zRhise" jsslot=""><span class="PkjLuf " title="babylontorino.it"><div class="OOHai">babylontorino.it<div class="qUFtbf"><div class="vhSllf" jsaction="click:cOuCgd" jscontroller="ifmJ5b"><span class="DPvwYc QiuYjb ERSyJd" data-column-type="12" data-value="babylontorino.it" title="Sao chép URL vào bảng nhớ tạm"></span></div><div class="vhSllf" jsaction="click:cOuCgd" jscontroller="ifmJ5b"><span class="DPvwYc QiuYjb Qb2M8" data-column-type="12" data-value="babylontorino.it" title="Mở trong thẻ mới"></span></div></div></div></span></span></td><td class="XgRaPc QNcORc HSWdnb XL1mme" data-numeric-value="764"><span class="zRhise" jsslot=""><span class="PkjLuf ">764<div class="qUFtbf"></div></span></span></td><td class="XgRaPc QNcORc HSWdnb XL1mme" data-numeric-value="14"><span class="zRhise" jsslot=""><span class="PkjLuf ">14<div class="qUFtbf"></div></span></span></td></tr>, <tr class="nJ0sOc wNFy3d ptEsvc " data-rowid="2" jsaction="click:AJI9fd;" jscontroller="qLYC9e" jsshadow=""><td class="XgRaPc AB6Eee QNcORc HSWdnb LoCYSb G49IUc chZ7Tc XL1mme"><span class="zRhise" jsslot=""><span class="PkjLuf " title="lombardovini.it"><div class="OOHai">lombardovini.it<div class="qUFtbf"><div class="vhSllf" jsaction="click:cOuCgd" jscontroller="ifmJ5b"><span class="DPvwYc QiuYjb ERSyJd" data-column-type="12" data-value="lombardovini.it" title="Sao chép URL vào bảng nhớ tạm"></span></div><div class="vhSllf" jsaction="click:cOuCgd" jscontroller="ifmJ5b"><span class="DPvwYc QiuYjb Qb2M8" data-column-type="12" data-value="lombardovini.it" title="Mở trong thẻ mới"></span></div></div></div></span></span></td><td class="XgRaPc QNcORc HSWdnb XL1mme" data-numeric-value="626"><span class="zRhise" jsslot=""><span class="PkjLuf ">626<div class="qUFtbf"></div></span></span></td><td class="XgRaPc QNcORc HSWdnb XL1mme" data-numeric-value="13"><span class="zRhise" jsslot=""><span class="PkjLuf ">13<div class="qUFtbf"></div></span></span></td></tr>, <tr class="nJ0sOc wNFy3d ptEsvc " data-rowid="3" jsaction="click:AJI9fd;" jscontroller="qLYC9e" jsshadow=""><td class="XgRaPc AB6Eee QNcORc HSWdnb LoCYSb G49IUc chZ7Tc XL1mme"><span class="zRhise" jsslot=""><span class="PkjLuf " title="pintarcochequatrecarreres.es"><div class="OOHai">pintarcochequatrecarreres.es<div class="qUFtbf"><div class="vhSllf" jsaction="click:cOuCgd" jscontroller="ifmJ5b"><span class="DPvwYc QiuYjb ERSyJd" data-column-type="12" data-value="pintarcochequatrecarreres.es" title="Sao chép URL vào bảng nhớ tạm"></span></div><div class="vhSllf" jsaction="click:cOuCgd" jscontroller="ifmJ5b"><span class="DPvwYc QiuYjb Qb2M8" data-column-type="12" data-value="pintarcochequatrecarreres.es" title="Mở trong thẻ mới"></span></div></div></div></spa ...

# %%
for externalDomain in g_data:
    #countchovui=countchovui+1
    #if countchovui<311:
    #  continue
    out = re.search(r'<div class="OOHai">(.*?(?=<))', str(externalDomain))
    rawdata=externalDomain.findAll("span", {"class": "PkjLuf"})
    URLList=out.group(1)
    print(URLList)
    urllink=rawdata[1].text
    urldest=rawdata[2].text
    url = f"https://search.google.com/search-console/links/drilldown?resource_id=https%3A%2F%2F{input}%2F&type=DOMAIN&target=&domain={URLList}"
    time.sleep(5)
    request = requests.get(url, headers=headers, cookies=cookies)
    soup_1 = BeautifulSoup(request.content, 'html.parser')
    count_step1=0
    for row in soup_1.findAll("tr", {"class": regex}):
      count_step1=count_step1+1
      if count_step1>100:
        break
      rawdata=row.findAll("span", {"class": "PkjLuf"})
      output = rawdata[0].text
      stripped_output = output.replace("", "")
      urllink_1=rawdata[1].text
      url_secondary = f"https://search.google.com/search-console/links/drilldown?resource_id=https%3A%2F%2F{input}%2F&type=DOMAIN&target={stripped_output}&domain={URLList}"
      time.sleep(3)
      request_secondary = requests.get(url_secondary, headers=headers, cookies=cookies)
      soup_secondary = BeautifulSoup(request_secondary.content, 'html.parser')
      count_step2=0
      for row_1 in soup_secondary.findAll("tr", {"class": regex}):
        count_step2=count_step2+1
        if count_step2>50:
          break
        rawdata2=row_1.findAll("span", {"class": "PkjLuf"})
        output_last = rawdata2[0].text.replace("", "")
        urldest_2=rawdata2[1].text.replace("", "")
        dfdomains = dfdomains.append(pd.DataFrame({"Trang web":[URLList],"Số trang liên kết":[urllink],"Số trang đích":[urldest],"Trang đích":[stripped_output],"Liên kết bên ngoài":[urllink_1],"Trang liên kết":[output_last],"URL đích (nếu khác nhau)":[urldest_2]}))
      #dfdomains = dfdomains.append(pd.DataFrame({"Trang web":"","Số trang liên kết":"","Số trang đích":"","Trang đích":[stripped_output],"Liên kết bên ngoài":[urllink_1],}))
    #dfdomains = dfdomains.append(pd.DataFrame({"Trang web":[URLList],"Số trang liên kết":[urllink],"Số trang đích":[urldest]}))
# kiwifarms.net
# guiadecostarica.com
# best-essay-writers.com
# gfycat.com
# b-bi.fr
# seekanswer.org
# avaipl.com
# tagpesa.com
# ferrarimotorcarsales.com
# qualitypeculiarities.com
# multipilarbalantika.co.id
# masterkeyusb.com
# ipcomputacion.cl
# fortalezaparaelalma.org
# finearts.go.th
# risingfaizabad.com
# starity.hu
# bitcointalk.org
# ccic-unesco.org
# kdpcommunity.com
# cbdandshrooms.com
# buycarbr.com.br
# logindigest.com
# reyesproperty.es
# paramountatl.com
# movingfromtheinside.com
# mpc.org.pe
# anetpa.com.cy
# trustimm.com
# 5bestthings.com
# diettnv.org
# civitas-abogados.cl
# gvi-turkey.com
# esturilio.adv.br
# alainlea.com
# turtc.com
# hilsenpestcontrol.com
# cunningsoft.de
# membromoneyflix.com
# teamverseinc.com
# small-bizsense.com
# pikohana.com
# domain.glass
# alabamareserve.com
# gosafelogin.com
# lurkmore.com
# esteticacherie.it
# azio.fr
# ulule.com
# slharchitecture.be
# lydspaintshop.co.uk
# footone.me
# crypto-faqs.com
# luckinair.com
# lesalfredes.org
# nyheadline.com
# infotelligent.com
# freshlookpaintingbarrie.com
# wikiz.com
# sanocare.ro
# 1againstracism.gr
# theworldinsiders.com
# alternativehealthtools.com
# mixcloud.com
# registrationhelper.com
# e-ambition.ma
# ethnoinformatique.fr
# theloginsystem.com
# szentgellertfesztival.hu
# dliplace.com
# mandysellars.com
# millhillcountryclub.com
# autoeletrovaleriorp.com.br
# amartakarya.co.id
# windowssearch-exp.com
# hirondelleq.fr
# star21tv.com
# mudralegal.in
# lastfrontierlawns.com
# xn--d1a1ac.xn--j1amh
# italianjob.pl
# wefoundhappiness.com
# free-ebooks.net
# 8tracks.com
# hsbc.com
# offshorereviews.com
# healthyhandsanitizer.com
# teksquadtech.com
# webflow.io
# producthunt.com
# wecalabria.it
# minnesotaheadline.com
# artbyrachael.com
# amrepmexico.net
# modangroup.com
# mypropty.com
# blogger.com
# ifconsultoria.com.br
# lms-ent.com
# worldstarbank.com
# kimmillerphoto.com
# alphagroupuae.com
# fincyte.com
# couponupto.com
# apsense.com
# marketersmedia.com
# vigoreplus.com
# financeguide.blog
# portugalexporta.com
# maharashtra.city
# bies.ro
# mundofilo.com
# expertdimond.com.br
# filipinowealth.com
# good-tutorials.com
# nordconnect.com
# painreliefindia.com
# vrijspreker.nl
# vox.com
# fichansraj.org
# masrelgadeda.com
# explorervan.co.kr
# mbanqitah.com
# artisan.com.hk
# xn--b3ca4am9c2exb8czb9a.com
# waterfrontvancouverusa.com
# knowyourmeme.com
# uagro.mx
# adarshcs.com
# mohammadrazamulla.com
# adinind.in
# rentmyownweeks.com
# laesquinaverde.com
# alostmind.com
# podomatic.com
# makemoneyq.com
# whitespotgym.com
# gab.com
# nationalpositions.com
# traditionslive.org
# startupguys.net
# nmedia-group.com
# cosechasus.com
# si.edu
# opole7dni.pl
# theafrocentrics.com
# thesignin.com
# maine.gov
# solardach-lissabon.de
# optimaltechnology.in
# rishtafast.com
# poliupg.ac.id
# softfina.com
# alabamaurologynetwork.com
# consultexpm.com
# note.com
# support-conseil.fr
# josefperl.com
# cj-lyon.co.uk
# iclou.com.br
# businessforum.uk
# theredeeminggracechurch.org
# viraltrench.com
# polski.wiki
# ameba.jp
# get-real-estate.info
# dikeyla.co.za
# deutsch-polnisches-jahr.de
# naitikawaj.com
# gptradingny.com
# slideserve.com
# techinexpert.com
# bhallajikitchen.com
# prosportsdaily.com
# lamanlega.com
# minds.com
# somo.nl
# citizensentinelsnetwork.com
# sarn-us.org
# lightsidefloats.com
# globalcallforwarding.com
# theartcult.net
# eldiariosp.com.ar
# compasso.med.br
# mozconcepts.com
# mojohost.com
# dingleystarsfc.com
# smart.reviews
# survivalblog.com
# businessvantageviews.com
# preface.ai
# finance-today.net
# bodykenko.fr
# connekt.me
# funkyretro.net
# technofaq.org
# rtvgroups.com
# credly.com
# biztoolspro.net
# rendezvouslasvegas.com
# cxcglobal.com
# jupyterlearn.com
# kubogroup.com.gt
# trello.com
# construactiva.com
# bitcointalksearch.org
# kenodowd.com.au
# lackestuc.es
# databaseor.com
# hot-shop.cc
# ardila.tv
# voeltnerphotography.com
# peacetime.world
# domy-michalowice.pl
# mysteryshoppersmanual.com
# darkhow.com
# az-lanzarote.de
# martinablatt.com
# piperemediation.com
# fordvinhnghean.com
# buyfromlo.com
# capitulomexico.com
# suluovagazete.com
# worldplaces.me
# nordsign.dk
# magneticfunctions.com
# smartbusinessdaily.com
# newsorator.com
# solution4acne.com
# bergcoast.com
# espec-tech.com
# 9thwave.co.uk
# corporacionsantaana.com
# evcc-registerednursing.com
# immobilier-ozoirlaferriere-era.fr
# infopvp.com
# purshology.com
# cool-tv.tv
# n4g.com
# mediasalon.com.my
# boomeressentials.com
# thekickassentrepreneur.com
# travellersmovement.org.uk
# buysellinvesting.com
# unitedworldtelecom.com
# agrrement-faq.com
# seattlesounders.org
# wemoveshemoves.me.uk
# guerradiaz.com
# nadlinc.io
# guiang.com
# 9ninelives.com
# login-wiki.com
# coachlinetraining.com
# optimbe.com
# kazwoods.com.au
# crunchbase.com
# mondostadia.com
# elvydent.com
# hugebazar.in
# ryenandtyree.com
# politicsforum.co.uk
# dayoplantation.com
# smatdesigns.com
# palrancho.co
# maxclubedebeneficios.org.br
# girlstoschool.org
# qsoftec.com
# facic.br
# shared-impact.com
# hulkshare.com
# topeleven.com
# yolasite.com
# techieheap.com
# cloodo.com
# rkbetfair.com
# racesociety.com
# about.me
# pokecommunity.com
# vorsoncattle.com
# comss.ru
# banklights.com
# smartstartbaby.com
# theminotaurgroup.com
# shorelinehicap.org
# archive.org
# saolourencomarmores.com.br
# unimus.ac.id
# allmyfaves.com
# alessandrobaldoni.it
# olimp.turystyka.pl
# oneterminals.com
# lookbook.nu
# neveravinoteca.com
# thehighoffice.com
# pawnshopshendersonnv.com
# anlogin.com
# northernsteelvic.com.au
# rb.ru
# psapm.com
# forumbrands.com
# 46digital.com.br
# firstservemiami.org
# studiotembo.com
# bestitems.in
# queirozeandrade.com.br
# iwate.org.br
# waschpark-mannersdorf.at
# gotradingasia.com
# uemigrate.com
# a2zdesigns.ca
# taichinhcuocsong.vn
# packageanalysis.com
# realestateinvestors.io
# storeboard.com
# scam-detector.com
# jrwmedia.pl
# scoop.it

# %%
with open(f"//content//sample_data/Backlink.csv", 'a') as file:
  dfdomains.to_csv('//content//sample_data/Backlink.csv')
  file.close()
